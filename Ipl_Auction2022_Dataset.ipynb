# %% [markdown]
# <a href="https://colab.research.google.com/github/SANAD343/IPL_Auction_DataSet_2022/blob/main/Ipl_Auction2022_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/sample_data/IPL Auction 2022_DataSet.csv")

# %%
df.head()
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M        R Ashwin         India              TNCA   35
# 1        1        M     Trent Boult   New Zealand               NaN   32
# 2        1        M     Pat Cummins     Australia               NaN   28
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 1       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# 2  ALL-ROUNDER     RHB        RIGHT ARM Fast   37.0         DD, MI, KKR
# 3      BATSMAN     LHB                     -  192.0    DCH, MI, SRH, DC
# 4      BATSMAN     RHB    RIGHT ARM Leg Spin  100.0            RPS, CSK
#
#   2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
df.ndim # Dimension of DataFrame
# Out:
# 2

# %%
df.shape # Shape of DataFrame
# Out:
# (184, 16)

# %%
df.size # Size of DataFrame
# Out:
# 2944

# %%
type(df)  # Type of DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe() # Returns description of the data in the DataFrame
# Out:
#           Set No.         Age         IPL
# count  184.000000  184.000000  137.000000
# mean    17.989130   27.103261   36.897810
# std     14.200742    4.428570   46.902635
# min      1.000000   17.000000    0.000000
# 25%      7.000000   24.000000    3.000000
# 50%     14.500000   27.000000   21.000000
# 75%     25.000000   30.250000   50.000000
# max     60.000000   38.000000  213.000000

# %%
df.head() #  Returns a specified number of rows, string from the top "by default top 5"
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M        R Ashwin         India              TNCA   35
# 1        1        M     Trent Boult   New Zealand               NaN   32
# 2        1        M     Pat Cummins     Australia               NaN   28
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 1       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# 2  ALL-ROUNDER     RHB        RIGHT ARM Fast   37.0         DD, MI, KKR
# 3      BATSMAN     LHB                     -  192.0    DCH, MI, SRH, DC
# 4      BATSMAN     RHB    RIGHT ARM Leg Spin  100.0            RPS, CSK
#
#   2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
df.tail()
# Out:
#      Set No. Set Name           Player Country State Association  Age  \
# 179       53     UAL8       Ansh Patel   India               BCA   20
# 180       54     UFA8     Ashok Sharma   India               RCA   19
# 181       57    UAL10  Arjun Tendulkar   India               MCA   22
# 182       59    UAL12  Shubham Garhwal   India               RCA   26
# 183       60    UAL13     Anunay Singh   India              BICA   29
#
#       Specialism Batting                   Bowling  IPL Previous IPLTeam(s)  \
# 179  ALL-ROUNDER     RHB  LEFT ARM Slow Unorthodox  NaN                 NaN
# 180       BOWLER     RHB     RIGHT ARM Fast Medium  NaN                 NaN
# 181  ALL-ROUNDER     LHB      LEFT ARM Fast Medium  0.0                  MI
# 182  ALL-ROUNDER     LHB    LEFT ARM Slow Orthodox  NaN                 NaN
# 183  ALL-ROUNDER     RHB     RIGHT ARM Fast Medium  NaN                 NaN
#
#     2021 Team     C/U/A Base Price Sold Price          New Franchise
# ...

# %%
for index,row in df.iterrows(): #Series Iter all rows according to the index.
  print(index,row)
# Out:
# 0 Set No.                                 1
# Set Name                                M
# Player                           R Ashwin
# Country                             India
# State Association                    TNCA
# Age                                    35
# Specialism                    ALL-ROUNDER
# Batting                               RHB
# Bowling                RIGHT ARM Off Spin
# IPL                                 167.0
# Previous IPLTeam(s)    CSK, RSP, KXIP, DC
# 2021 Team                              DC
# C/U/A                              Capped
# Base Price                           2 CR
# Sold Price                           5 CR
# New Franchise            Rajasthan Royals
# Name: 0, dtype: object
# 1 Set No.                                   1
# Set Name                                  M
# Player                          Trent Boult
# Country                         New Zealand
# State Association                       NaN
# ...

# %%
df.columns  # Attribute returns the column labels of the given Dataframe.
# Out:
# Index(['Set No.', 'Set Name', 'Player', 'Country', 'State Association', 'Age',
#        'Specialism', 'Batting', 'Bowling', 'IPL', 'Previous IPLTeam(s)',
#        '2021 Team', 'C/U/A', 'Base Price', 'Sold Price', 'New Franchise'],
#       dtype='object')

# %%
#df.row will not works

# %%
df["Player"] # all players data from DataFrame
# Out:
# 0             R Ashwin
# 1          Trent Boult
# 2          Pat Cummins
# 3       Shikhar Dhawan
# 4       Faf Du Plessis
#             ...
# 179         Ansh Patel
# 180       Ashok Sharma
# 181    Arjun Tendulkar
# 182    Shubham Garhwal
# 183       Anunay Singh
# Name: Player, Length: 184, dtype: object

# %%
df["Player"].values #  Attribute return a Numpy representation of the given DataFrame.
# Out:
# array(['R Ashwin', 'Trent Boult', 'Pat Cummins', 'Shikhar Dhawan',
#        'Faf Du Plessis', 'Shreyas Iyer', 'Kagiso Rabada',
#        'Mohammad Shami', 'David Warner', 'Shimron Hetmyer',
#        'David Miller', 'Devdutt Padikkal', 'Manish Pandey', 'Jason Roy',
#        'Robin Uthappa', 'Dwayne Bravo', 'Wanindu Hasaranga',
#        'Jason Holder', 'Mitchell Marsh', 'Krunal Pandya', 'Harshal Patel',
#        'Nitish Rana', 'Washington Sundar', 'Jonny Bairstow',
#        'Sam Billings', 'Dinesh Karthik', 'Ishan Kishan',
#        'Nicholas Pooran', 'Ambati Rayudu', 'Matthew Wade',
#        'Deepak Chahar', 'Lockie Ferguson', 'Josh Hazlewood',
#        'Prasidh Krishna', 'Bhuvneshwar Kumar', 'Mustafizur Rahman',
#        'Shardul Thakur', 'Mark Wood', 'Umesh Yadav', 'Yuzvendra Chahal',
#        'Rahul Chahar', 'Kuldeep Yadav', 'Dewald Brevis', 'Priyam Garg',
#        'Ashwin Hebbar', 'Abhinav Sadarangani', 'Anmolpreet Singh',
# ...

# %%
df["Country"].to_list() #Converted Country column data into list
# Out:
# ['India',
#  'New Zealand',
#  'Australia',
#  'India',
#  'South Africa',
#  'India',
#  'South Africa',
#  'India',
#  'Australia',
#  'West Indies',
#  'South Africa',
#  'India',
#  'India',
#  'England',
#  'India',
#  'West Indies',
#  'Sri Lanka',
#  'West Indies',
#  'Australia',
#  'India',
#  'India',
#  'India',
#  'India',
#  'England',
#  'England',
#  'India',
#  'India',
#  'West Indies',
#  'India',
#  'Australia',
#  'India',
#  'New Zealand',
#  'Australia',
#  'India',
#  'India',
#  'Bangladesh',
#  'India',
#  'England',
#  'India',
#  'India',
#  'India',
#  'India',
#  'South Africa',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Afghanistan',
#  'India',
#  'India',
#  'India',
# ...

# %%
df[["Player","Country"]] # 2 different column in DataFrame
# Out:
#               Player       Country
# 0           R Ashwin         India
# 1        Trent Boult   New Zealand
# 2        Pat Cummins     Australia
# 3     Shikhar Dhawan         India
# 4     Faf Du Plessis  South Africa
# ..               ...           ...
# 179       Ansh Patel         India
# 180     Ashok Sharma         India
# 181  Arjun Tendulkar         India
# 182  Shubham Garhwal         India
# 183     Anunay Singh         India
#
# [184 rows x 2 columns]

# %%
df.dtypes # Type of DataFrame
# Out:
# Set No.                  int64
# Set Name                object
# Player                  object
# Country                 object
# State Association       object
# Age                      int64
# Specialism              object
# Batting                 object
# Bowling                 object
# IPL                    float64
# Previous IPLTeam(s)     object
# 2021 Team               object
# C/U/A                   object
# Base Price              object
# Sold Price              object
# New Franchise           object
# dtype: object

# %%
type(df.shape) # Type of DataFrame of shape Column
# Out:
# tuple

# %%
df.sample() #we can add numbers in paranthesis if we need specific number of data
# Out:
#    Set No. Set Name           Player      Country State Association  Age  \
# 9        2      BA1  Shimron Hetmyer  West Indies               NaN   25
#
#   Specialism Batting             Bowling   IPL Previous IPLTeam(s) 2021 Team  \
# 9    BATSMAN     LHB  RIGHT ARM Leg Spin  31.0             RCB, DC        DC
#
#     C/U/A Base Price Sold Price     New Franchise
# 9  Capped     1.5 CR     8.5 CR  Rajasthan Royals

# %%
#dir(df) #gives all the function buit-in under the pandas dir(DataFrame)

# %%
df.axes # This attribute is used to access the group of rows and columns labels of the given DataFrame.
# Out:
# [RangeIndex(start=0, stop=184, step=1),
#  Index(['Set No.', 'Set Name', 'Player', 'Country', 'State Association', 'Age',
#         'Specialism', 'Batting', 'Bowling', 'IPL', 'Previous IPLTeam(s)',
#         '2021 Team', 'C/U/A', 'Base Price', 'Sold Price', 'New Franchise'],
#        dtype='object')]

# %%
df["Sold Price"]
# Out:
# 0         5 CR
# 1         8 CR
# 2      7.25 CR
# 3      8.25 CR
# 4         7 CR
#         ...
# 179       20 L
# 180       55 L
# 181       30 L
# 182       20 L
# 183       20 L
# Name: Sold Price, Length: 184, dtype: object

# %%
df[["Base Price","Sold Price"]]
# Out:
#     Base Price Sold Price
# 0         2 CR       5 CR
# 1         2 CR       8 CR
# 2         2 CR    7.25 CR
# 3         2 CR    8.25 CR
# 4         2 CR       7 CR
# ..         ...        ...
# 179       20 L       20 L
# 180       20 L       55 L
# 181       20 L       30 L
# 182       20 L       20 L
# 183       20 L       20 L
#
# [184 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Set No.', 'Set Name', 'Player', 'Country', 'State Association', 'Age',
#        'Specialism', 'Batting', 'Bowling', 'IPL', 'Previous IPLTeam(s)',
#        '2021 Team', 'C/U/A', 'Base Price', 'Sold Price', 'New Franchise'],
#       dtype='object')

# %%
df[5:10] # Slicing, got all data from 5th row to 9th row
# Out:
#    Set No. Set Name           Player       Country State Association  Age  \
# 5        1        M     Shreyas Iyer         India               MCA   27
# 6        1        M    Kagiso Rabada  South Africa               NaN   26
# 7        1        M   Mohammad Shami         India               CAB   32
# 8        1        M     David Warner     Australia               NaN   35
# 9        2      BA1  Shimron Hetmyer   West Indies               NaN   25
#
#   Specialism Batting             Bowling    IPL Previous IPLTeam(s) 2021 Team  \
# 5    BATSMAN     RHB  RIGHT ARM Leg Spin   87.0                  DC        DC
# 6     BOWLER     LHB      RIGHT ARM Fast   50.0                  DC        DC
# 7     BOWLER     RHB      RIGHT ARM Fast   77.0  DCH, KKR, DD, PBKS      PBKS
# 8    BATSMAN     LHB                   -  150.0             DD, SRH       SRH
# 9    BATSMAN     LHB  RIGHT ARM Leg Spin   31.0             RCB, DC        DC
#
# ...

# %%
df.loc[5:10] # Use of loc, and got all data from 5th row to 10th row
# Out:
#     Set No. Set Name           Player       Country State Association  Age  \
# 5         1        M     Shreyas Iyer         India               MCA   27
# 6         1        M    Kagiso Rabada  South Africa               NaN   26
# 7         1        M   Mohammad Shami         India               CAB   32
# 8         1        M     David Warner     Australia               NaN   35
# 9         2      BA1  Shimron Hetmyer   West Indies               NaN   25
# 10        2      BA1     David Miller  South Africa               NaN   32
#
#    Specialism Batting             Bowling    IPL Previous IPLTeam(s)  \
# 5     BATSMAN     RHB  RIGHT ARM Leg Spin   87.0                  DC
# 6      BOWLER     LHB      RIGHT ARM Fast   50.0                  DC
# 7      BOWLER     RHB      RIGHT ARM Fast   77.0  DCH, KKR, DD, PBKS
# 8     BATSMAN     LHB                   -  150.0             DD, SRH
# 9     BATSMAN     LHB  RIGHT ARM Leg Spin   31.0             RCB, DC
# ...

# %%
# Slicing got all players name from 11th to 17th row as we didn't use loc
df["Player"][11:18]
# Out:
# 11     Devdutt Padikkal
# 12        Manish Pandey
# 13            Jason Roy
# 14        Robin Uthappa
# 15         Dwayne Bravo
# 16    Wanindu Hasaranga
# 17         Jason Holder
# Name: Player, dtype: object

# %%
df.loc[8] #Got detail for 8th row
# Out:
# Set No.                             1
# Set Name                            M
# Player                   David Warner
# Country                     Australia
# State Association                 NaN
# Age                                35
# Specialism                    BATSMAN
# Batting                           LHB
# Bowling                             -
# IPL                             150.0
# Previous IPLTeam(s)           DD, SRH
# 2021 Team                         SRH
# C/U/A                          Capped
# Base Price                       2 CR
# Sold Price                    6.25 CR
# New Franchise          Delhi Capitals
# Name: 8, dtype: object

# %%
# Got all details from 2nd row till 8th row as we have use loc,
#without loc we can get result from 2nd row till 7th row
df.loc[2:8]
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 2        1        M     Pat Cummins     Australia               NaN   28
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
# 5        1        M    Shreyas Iyer         India               MCA   27
# 6        1        M   Kagiso Rabada  South Africa               NaN   26
# 7        1        M  Mohammad Shami         India               CAB   32
# 8        1        M    David Warner     Australia               NaN   35
#
#     Specialism Batting             Bowling    IPL Previous IPLTeam(s)  \
# 2  ALL-ROUNDER     RHB      RIGHT ARM Fast   37.0         DD, MI, KKR
# 3      BATSMAN     LHB                   -  192.0    DCH, MI, SRH, DC
# 4      BATSMAN     RHB  RIGHT ARM Leg Spin  100.0            RPS, CSK
# 5      BATSMAN     RHB  RIGHT ARM Leg Spin   87.0                  DC
# ...

# %%
df.loc[df["Set Name"]=="M"] # All Data With Set Name ==M
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M        R Ashwin         India              TNCA   35
# 1        1        M     Trent Boult   New Zealand               NaN   32
# 2        1        M     Pat Cummins     Australia               NaN   28
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
# 5        1        M    Shreyas Iyer         India               MCA   27
# 6        1        M   Kagiso Rabada  South Africa               NaN   26
# 7        1        M  Mohammad Shami         India               CAB   32
# 8        1        M    David Warner     Australia               NaN   35
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 1       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# ...

# %%
df.loc[df["Country"]=="India"] #All Indian Player
# Out:
#      Set No. Set Name            Player Country State Association  Age  \
# 0          1        M          R Ashwin   India              TNCA   35
# 3          1        M    Shikhar Dhawan   India              DDCA   36
# 5          1        M      Shreyas Iyer   India               MCA   27
# 7          1        M    Mohammad Shami   India               CAB   32
# 11         2      BA1  Devdutt Padikkal   India              KSCA   21
# ..       ...      ...               ...     ...               ...  ...
# 179       53     UAL8        Ansh Patel   India               BCA   20
# 180       54     UFA8      Ashok Sharma   India               RCA   19
# 181       57    UAL10   Arjun Tendulkar   India               MCA   22
# 182       59    UAL12   Shubham Garhwal   India               RCA   26
# 183       60    UAL13      Anunay Singh   India              BICA   29
#
#       Specialism Batting                   Bowling    IPL Previous IPLTeam(s)  \
# ...

# %%
df.loc[df["Age"]>30] #all palyers with age above 30
# Out:
#      Set No. Set Name               Player       Country State Association  \
# 0          1        M             R Ashwin         India              TNCA
# 1          1        M          Trent Boult   New Zealand               NaN
# 3          1        M       Shikhar Dhawan         India              DDCA
# 4          1        M       Faf Du Plessis  South Africa               NaN
# 7          1        M       Mohammad Shami         India               CAB
# 8          1        M         David Warner     Australia               NaN
# 10         2      BA1         David Miller  South Africa               NaN
# 12         2      BA1        Manish Pandey         India              KSCA
# 13         2      BA1            Jason Roy       England               NaN
# 14         2      BA1        Robin Uthappa         India               KCA
# 15         3      AL1         Dwayne Bravo   West Indies               NaN
# ...

# %%
df.loc[df["Age"]>30].head(5) #all palyers with above 30 age top 5 result only
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M        R Ashwin         India              TNCA   35
# 1        1        M     Trent Boult   New Zealand               NaN   32
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
# 7        1        M  Mohammad Shami         India               CAB   32
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 1       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# 3      BATSMAN     LHB                     -  192.0    DCH, MI, SRH, DC
# 4      BATSMAN     RHB    RIGHT ARM Leg Spin  100.0            RPS, CSK
# 7       BOWLER     RHB        RIGHT ARM Fast   77.0  DCH, KKR, DD, PBKS
#
#   2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
#all palyers with above 30 age but only indaian player
# &- Bitwise And Operator is using here to check one conditiion if 1st condition is tru then it will check for 2nd condition.
df.loc[(df["Country"]=="India")&(df["Age"]>30)]
# Out:
#      Set No. Set Name             Player Country State Association  Age  \
# 0          1        M           R Ashwin   India              TNCA   35
# 3          1        M     Shikhar Dhawan   India              DDCA   36
# 7          1        M     Mohammad Shami   India               CAB   32
# 12         2      BA1      Manish Pandey   India              KSCA   32
# 14         2      BA1      Robin Uthappa   India               KCA   36
# 19         3      AL1      Krunal Pandya   India               BCA   31
# 20         3      AL1      Harshal Patel   India               HCA   31
# 25         4      WK1     Dinesh Karthik   India              TNCA   36
# 28         4      WK1      Ambati Rayudu   India               ACA   36
# 34         5      FA1  Bhuvneshwar Kumar   India              UPCA   32
# 38         5      FA1        Umesh Yadav   India               VCA   34
# 39         6      SP1   Yuzvendra Chahal   India               HCA   31
# ...

# %%
 # All indian Player with above age of 30
df.loc[(df["Country"]=="India")&(df["Age"]>30)].head(5)
# Out:
#     Set No. Set Name          Player Country State Association  Age  \
# 0         1        M        R Ashwin   India              TNCA   35
# 3         1        M  Shikhar Dhawan   India              DDCA   36
# 7         1        M  Mohammad Shami   India               CAB   32
# 12        2      BA1   Manish Pandey   India              KSCA   32
# 14        2      BA1   Robin Uthappa   India               KCA   36
#
#      Specialism Batting             Bowling    IPL  \
# 0   ALL-ROUNDER     RHB  RIGHT ARM Off Spin  167.0
# 3       BATSMAN     LHB                   -  192.0
# 7        BOWLER     RHB      RIGHT ARM Fast   77.0
# 12      BATSMAN     RHB  RIGHT ARM Off Spin  154.0
# 14      BATSMAN     RHB                   -  193.0
#
#            Previous IPLTeam(s) 2021 Team   C/U/A Base Price Sold Price  \
# 0           CSK, RSP, KXIP, DC        DC  Capped       2 CR       5 CR
# 3             DCH, MI, SRH, DC        DC  Capped       2 CR    8.25 CR
# ...

# %%
#pull all player with Capitol S.
df.loc[df["Player"].str.startswith("S")]
# Out:
#      Set No. Set Name               Player      Country State Association  \
# 3          1        M       Shikhar Dhawan        India              DDCA
# 5          1        M         Shreyas Iyer        India               MCA
# 9          2      BA1      Shimron Hetmyer  West Indies               NaN
# 24         4      WK1         Sam Billings      England               NaN
# 36         5      FA1       Shardul Thakur        India               MCA
# 48         8     UAL1       Shahbaz Ahamad        India               CAB
# 51         8     UAL1        Sarfaraz Khan        India               MCA
# 52         8     UAL1        Shahrukh Khan        India              TNCA
# 53         8     UAL1          Shivam Mavi        India              UPCA
# 58         9     UWK1      Sheldon Jackson        India               SCA
# 71        11     USP1        Shreyas Gopal        India              KSCA
# 77        13      AL2          Shivam Dube        India               MCA
# ...

# %%
#all players without "S"
df.loc[~df["Player"].str.startswith("S")] #using ~
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# 6          1        M    Kagiso Rabada  South Africa               NaN   26
# ..       ...      ...              ...           ...               ...  ...
# 178       52     UFA7      Lalit Yadav         India               VCA   26
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
#information of players with respect to country,
#all player of WestIndies starts with capital S
df.loc[(df["Player"].str.contains("S"))&(df["Country"]=="West Indies")]
# Out:
#      Set No. Set Name               Player      Country State Association  \
# 9          2      BA1      Shimron Hetmyer  West Indies               NaN
# 84        13      AL2          Odean Smith  West Indies               NaN
# 120       20      AL3  Sherfane Rutherford  West Indies               NaN
# 123       20      AL3     Romario Shepherd  West Indies               NaN
#
#      Age   Specialism Batting                Bowling   IPL  \
# 9     25      BATSMAN     LHB     RIGHT ARM Leg Spin  31.0
# 84    25  ALL-ROUNDER     RHB         RIGHT ARM Fast   NaN
# 120   23  ALL-ROUNDER     LHB       RIGHT ARM Medium   7.0
# 123   27  ALL-ROUNDER     RHB  RIGHT ARM Fast Medium   NaN
#
#     Previous IPLTeam(s) 2021 Team   C/U/A Base Price Sold Price  \
# 9               RCB, DC        DC  Capped     1.5 CR     8.5 CR
# 84                  NaN       NaN  Capped       1 CR       6 CR
# 120              DC, MI       NaN  Capped       1 CR       1 CR
# ...

# %%
# Pulling all players till 10th column Method 1
df["Player"][:10]
# Out:
# 0           R Ashwin
# 1        Trent Boult
# 2        Pat Cummins
# 3     Shikhar Dhawan
# 4     Faf Du Plessis
# 5       Shreyas Iyer
# 6      Kagiso Rabada
# 7     Mohammad Shami
# 8       David Warner
# 9    Shimron Hetmyer
# Name: Player, dtype: object

# %%
# Pulling all players using head function Method 2
df["Player"].head(3)
# Out:
# 0       R Ashwin
# 1    Trent Boult
# 2    Pat Cummins
# Name: Player, dtype: object

# %%
#exclude first four entries
df.tail(-4)
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# 5          1        M     Shreyas Iyer         India               MCA   27
# 6          1        M    Kagiso Rabada  South Africa               NaN   26
# 7          1        M   Mohammad Shami         India               CAB   32
# 8          1        M     David Warner     Australia               NaN   35
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
df.head(-4) #exclude last 4 rows
# Out:
#      Set No. Set Name          Player       Country State Association  Age  \
# 0          1        M        R Ashwin         India              TNCA   35
# 1          1        M     Trent Boult   New Zealand               NaN   32
# 2          1        M     Pat Cummins     Australia               NaN   28
# 3          1        M  Shikhar Dhawan         India              DDCA   36
# 4          1        M  Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...             ...           ...               ...  ...
# 175       51     UAL7    Karan Sharma         India              UPCA   23
# 176       52     UFA7   Baltej Dhanda         India               PCA   31
# 177       52     UFA7   Saurabh Dubey         India               VCA   24
# 178       52     UFA7     Lalit Yadav         India               VCA   26
# 179       53     UAL8      Ansh Patel         India               BCA   20
#
# ...

# %%
df.loc[3:6] #slicing using loc, got all details form 3rd to 6th row.
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
# 5        1        M    Shreyas Iyer         India               MCA   27
# 6        1        M   Kagiso Rabada  South Africa               NaN   26
#
#   Specialism Batting             Bowling    IPL Previous IPLTeam(s) 2021 Team  \
# 3    BATSMAN     LHB                   -  192.0    DCH, MI, SRH, DC        DC
# 4    BATSMAN     RHB  RIGHT ARM Leg Spin  100.0            RPS, CSK       CSK
# 5    BATSMAN     RHB  RIGHT ARM Leg Spin   87.0                  DC        DC
# 6     BOWLER     LHB      RIGHT ARM Fast   50.0                  DC        DC
#
#     C/U/A Base Price Sold Price                New Franchise
# 3  Capped       2 CR    8.25 CR                 Punjab Kings
# 4  Capped       2 CR       7 CR  Royal Challengers Bangalore
# ...

# %%
df.loc[3:16:2] #all deatils from 3 to 16 with stepping of 2
# Out:
#     Set No. Set Name            Player      Country State Association  Age  \
# 3         1        M    Shikhar Dhawan        India              DDCA   36
# 5         1        M      Shreyas Iyer        India               MCA   27
# 7         1        M    Mohammad Shami        India               CAB   32
# 9         2      BA1   Shimron Hetmyer  West Indies               NaN   25
# 11        2      BA1  Devdutt Padikkal        India              KSCA   21
# 13        2      BA1         Jason Roy      England               NaN   31
# 15        3      AL1      Dwayne Bravo  West Indies               NaN   38
#
#      Specialism Batting                Bowling    IPL Previous IPLTeam(s)  \
# 3       BATSMAN     LHB                      -  192.0    DCH, MI, SRH, DC
# 5       BATSMAN     RHB     RIGHT ARM Leg Spin   87.0                  DC
# 7        BOWLER     RHB         RIGHT ARM Fast   77.0  DCH, KKR, DD, PBKS
# ...

# %%
df[3:6] #without loc, only got 3rd to 5th row
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
# 5        1        M    Shreyas Iyer         India               MCA   27
#
#   Specialism Batting             Bowling    IPL Previous IPLTeam(s) 2021 Team  \
# 3    BATSMAN     LHB                   -  192.0    DCH, MI, SRH, DC        DC
# 4    BATSMAN     RHB  RIGHT ARM Leg Spin  100.0            RPS, CSK       CSK
# 5    BATSMAN     RHB  RIGHT ARM Leg Spin   87.0                  DC        DC
#
#     C/U/A Base Price Sold Price                New Franchise
# 3  Capped       2 CR    8.25 CR                 Punjab Kings
# 4  Capped       2 CR       7 CR  Royal Challengers Bangalore
# 5  Capped       2 CR   12.25 CR        Kolkata Knight Riders

# %%
df.loc[df["Batting"]=="LHB"].head(5) # All players with batting style LHB
# Out:
#     Set No. Set Name           Player       Country State Association  Age  \
# 3         1        M   Shikhar Dhawan         India              DDCA   36
# 6         1        M    Kagiso Rabada  South Africa               NaN   26
# 8         1        M     David Warner     Australia               NaN   35
# 9         2      BA1  Shimron Hetmyer   West Indies               NaN   25
# 10        2      BA1     David Miller  South Africa               NaN   32
#
#    Specialism Batting             Bowling    IPL Previous IPLTeam(s)  \
# 3     BATSMAN     LHB                   -  192.0    DCH, MI, SRH, DC
# 6      BOWLER     LHB      RIGHT ARM Fast   50.0                  DC
# 8     BATSMAN     LHB                   -  150.0             DD, SRH
# 9     BATSMAN     LHB  RIGHT ARM Leg Spin   31.0             RCB, DC
# 10    BATSMAN     LHB                   -   89.0            KXIP, RR
#
#    2021 Team   C/U/A Base Price Sold Price     New Franchise
# ...

# %%
df.loc[(df["Batting"]=="LHB") & (df["Specialism"]=="WICKETKEEPER")]  # All players with batting style LHB & specialism of wicketkeeper
# Out:
#      Set No. Set Name           Player      Country State Association  Age  \
# 26         4      WK1     Ishan Kishan        India              JSCA   23
# 27         4      WK1  Nicholas Pooran  West Indies               NaN   26
# 29         4      WK1     Matthew Wade    Australia               NaN   34
# 59         9     UWK1       Anuj Rawat        India              DDCA   22
# 141       26     UWK2  Luvnith Sisodia        India              KSCA   22
#
#        Specialism Batting             Bowling   IPL Previous IPLTeam(s)  \
# 26   WICKETKEEPER     LHB                   -  61.0             GL , MI
# 27   WICKETKEEPER     LHB                   -  33.0            MI, PBKS
# 29   WICKETKEEPER     LHB                   -   3.0                  DD
# 59   WICKETKEEPER     LHB                   -   2.0                  RR
# 141  WICKETKEEPER     LHB  RIGHT ARM Off Spin   NaN                 NaN
#
#     2021 Team     C/U/A Base Price Sold Price                New Franchise
# ...

# %%
#filttering out of data, withrespect to batting, specialism & country
df.loc[(df["Batting"]=="LHB") & (df["Specialism"]=="WICKETKEEPER") & (df["Country"]=="West Indies")]
# Out:
#     Set No. Set Name           Player      Country State Association  Age  \
# 27        4      WK1  Nicholas Pooran  West Indies               NaN   26
#
#       Specialism Batting Bowling   IPL Previous IPLTeam(s) 2021 Team   C/U/A  \
# 27  WICKETKEEPER     LHB       -  33.0            MI, PBKS      PBKS  Capped
#
#    Base Price Sold Price        New Franchise
# 27     1.5 CR   10.75 CR  Sunrisers Hyderabad

# %%
#filttering out of data, withrespect to batting. specialism & country
df.loc[(df["Batting"]=="LHB") & (df["Specialism"]=="Bowler") & (df["Country"]=="India")]
# Out:
# Empty DataFrame
# Columns: [Set No., Set Name, Player, Country, State Association, Age, Specialism, Batting, Bowling, IPL, Previous IPLTeam(s), 2021 Team, C/U/A, Base Price, Sold Price, New Franchise]
# Index: []

# %%
#filttering out of data, withrespect to batting. specialism & country and top 5 result only
df.loc[(df["Batting"]=="RHB") & (df["Specialism"]=="BOWLER") & (df["Country"]=="India")].head(5)
# Out:
#     Set No. Set Name             Player Country State Association  Age  \
# 7         1        M     Mohammad Shami   India               CAB   32
# 30        5      FA1      Deepak Chahar   India               RCA   29
# 33        5      FA1    Prasidh Krishna   India              KSCA   26
# 34        5      FA1  Bhuvneshwar Kumar   India              UPCA   32
# 36        5      FA1     Shardul Thakur   India               MCA   30
#
#    Specialism Batting                Bowling    IPL Previous IPLTeam(s)  \
# 7      BOWLER     RHB         RIGHT ARM Fast   77.0  DCH, KKR, DD, PBKS
# 30     BOWLER     RHB  RIGHT ARM Fast Medium   63.0            RPS, CSK
# 33     BOWLER     RHB         RIGHT ARM Fast   34.0                 KKR
# 34     BOWLER     RHB  RIGHT ARM Fast Medium  132.0            PWI, SRH
# 36     BOWLER     RHB  RIGHT ARM Fast Medium   61.0      KXIP, RPS, CSK
#
#    2021 Team   C/U/A Base Price Sold Price        New Franchise
# ...

# %%
#filttering out of data
df.loc[(df["Batting"]=="RHB") & (df["Specialism"]=="ALL-ROUNDER") & (df["Country"]=="India")].head(5)
# Out:
#     Set No. Set Name         Player Country State Association  Age  \
# 0         1        M       R Ashwin   India              TNCA   35
# 20        3      AL1  Harshal Patel   India               HCA   31
# 50        8     UAL1   Deepak Hooda   India               RCA   26
# 51        8     UAL1  Sarfaraz Khan   India               MCA   24
# 52        8     UAL1  Shahrukh Khan   India              TNCA   26
#
#      Specialism Batting                Bowling    IPL Previous IPLTeam(s)  \
# 0   ALL-ROUNDER     RHB     RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 20  ALL-ROUNDER     RHB  RIGHT ARM Fast Medium   63.0             DC, RCB
# 50  ALL-ROUNDER     RHB     RIGHT ARM Off Spin   80.0       RR, SRH, PBKS
# 51  ALL-ROUNDER     RHB     RIGHT ARM Leg Spin   40.0            RCB,PBKS
# 52  ALL-ROUNDER     RHB     RIGHT ARM Off Spin   11.0                PBKS
#
#    2021 Team     C/U/A Base Price Sold Price                New Franchise
# ...

# %%
# use of | Bitwise OR operators
df.loc[(df["Batting"]=="RHB") & (df["Specialism"]=="ALL-ROUNDER") | (df["Country"]=="South Africa")].head(5)
# Out:
#     Set No. Set Name          Player       Country State Association  Age  \
# 0         1        M        R Ashwin         India              TNCA   35
# 2         1        M     Pat Cummins     Australia               NaN   28
# 4         1        M  Faf Du Plessis  South Africa               NaN   37
# 6         1        M   Kagiso Rabada  South Africa               NaN   26
# 10        2      BA1    David Miller  South Africa               NaN   32
#
#      Specialism Batting             Bowling    IPL Previous IPLTeam(s)  \
# 0   ALL-ROUNDER     RHB  RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 2   ALL-ROUNDER     RHB      RIGHT ARM Fast   37.0         DD, MI, KKR
# 4       BATSMAN     RHB  RIGHT ARM Leg Spin  100.0            RPS, CSK
# 6        BOWLER     LHB      RIGHT ARM Fast   50.0                  DC
# 10      BATSMAN     LHB                   -   89.0            KXIP, RR
#
#    2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
#player with age leas then 20 and batting stlye LHB
df.loc[(df["Batting"]=="LHB") & (df["Age"]<20)]
# Out:
#      Set No. Set Name            Player Country State Association  Age  \
# 158       33     UAL4  Aneeshwar Gautam   India              KSCA   19
#
#       Specialism Batting                 Bowling  IPL Previous IPLTeam(s)  \
# 158  ALL-ROUNDER     LHB  LEFT ARM Slow Orthodox  NaN                 NaN
#
#     2021 Team     C/U/A Base Price Sold Price                New Franchise
# 158       NaN  Uncapped       20 L       20 L  Royal Challengers Bangalore

# %%
 #player with age leas then 20 and batting stlye RHB
df.loc[(df["Batting"]=="RHB") & (df["Age"]<20)]
# Out:
#      Set No. Set Name                  Player       Country State Association  \
# 42         7     UBA1           Dewald Brevis  South Africa               NaN
# 69        11     USP1              Noor Ahmad   Afghanistan               NaN
# 98        17     UAL2              Yash Dhull         India              DDCA
# 99        17     UAL2  Rajvardhan Hangargekar         India              MACA
# 102       17     UAL2            Vicky Ostwal         India              MACA
# 147       27     UFA3            Mayank Yadav         India              DDCA
# 180       54     UFA8            Ashok Sharma         India               RCA
#
#      Age   Specialism Batting                   Bowling  IPL  \
# 42    18      BATSMAN     RHB        RIGHT ARM Leg Spin  NaN
# 69    17       BOWLER     RHB  LEFT ARM Slow Unorthodox  NaN
# 98    19  ALL-ROUNDER     RHB        RIGHT ARM Off Spin  NaN
# 99    19  ALL-ROUNDER     RHB            RIGHT ARM Fast  NaN
# ...

# %%
# All Players from Afghanistan
df.loc[(df["Country"]=="Afghanistan")]
# Out:
#      Set No. Set Name            Player      Country State Association  Age  \
# 69        11     USP1        Noor Ahmad  Afghanistan               NaN   17
# 128       22      FA3  Fazalhaq Farooqi  Afghanistan               NaN   21
#
#     Specialism Batting                   Bowling  IPL Previous IPLTeam(s)  \
# 69      BOWLER     RHB  LEFT ARM Slow Unorthodox  NaN                 NaN
# 128     BOWLER     RHB      LEFT ARM Fast Medium  NaN                 NaN
#
#     2021 Team     C/U/A Base Price Sold Price        New Franchise
# 69        NaN  Uncapped       30 L       30 L       Gujarat Titans
# 128       NaN    Capped       50 L       50 L  Sunrisers Hyderabad

# %%
#Player containing U in their name
df.loc[df["Player"].str.contains("U")]
# Out:
#     Set No. Set Name          Player Country State Association  Age  \
# 14        2      BA1   Robin Uthappa   India               KCA   36
# 38        5      FA1     Umesh Yadav   India               VCA   34
# 91       14      FA2  Jaydev Unadkat   India               SCA   30
#
#    Specialism Batting               Bowling    IPL  \
# 14    BATSMAN     RHB                     -  193.0
# 38     BOWLER     RHB        RIGHT ARM Fast  121.0
# 91     BOWLER     RHB  LEFT ARM Fast Medium   86.0
#
#            Previous IPLTeam(s) 2021 Team   C/U/A Base Price Sold Price  \
# 14  MI, PWI, RCB, KKR, RR, CSK       CSK  Capped       2 CR       2 CR
# 38              DD, KKR,RCB,DC        DC  Capped       2 CR       2 CR
# 91        KKR,RCB, DD, RPS, RR        RR  Capped       75 L    1.30 CR
#
#             New Franchise
# 14    Chennai Super Kings
# 38  Kolkata Knight Riders
# 91         Mumbai Indians

# %%
#Player containing s in their name, top 5 result
df.loc[df["Player"].str.contains("s")].head(5)
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M        R Ashwin         India              TNCA   35
# 2        1        M     Pat Cummins     Australia               NaN   28
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
# 5        1        M    Shreyas Iyer         India               MCA   27
# 6        1        M   Kagiso Rabada  South Africa               NaN   26
#
#     Specialism Batting             Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB  RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 2  ALL-ROUNDER     RHB      RIGHT ARM Fast   37.0         DD, MI, KKR
# 4      BATSMAN     RHB  RIGHT ARM Leg Spin  100.0            RPS, CSK
# 5      BATSMAN     RHB  RIGHT ARM Leg Spin   87.0                  DC
# 6       BOWLER     LHB      RIGHT ARM Fast   50.0                  DC
#
#   2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
#Player containing u in their name
df.loc[df["Player"].str.contains("u")]
# Out:
#      Set No. Set Name               Player       Country State Association  \
# 1          1        M          Trent Boult   New Zealand               NaN
# 2          1        M          Pat Cummins     Australia               NaN
# 4          1        M       Faf Du Plessis  South Africa               NaN
# 11         2      BA1     Devdutt Padikkal         India              KSCA
# 16         3      AL1    Wanindu Hasaranga     Sri Lanka               NaN
# 19         3      AL1        Krunal Pandya         India               BCA
# 22         3      AL1    Washington Sundar         India              TNCA
# 28         4      WK1        Ambati Rayudu         India               ACA
# 31         5      FA1      Lockie Ferguson   New Zealand               NaN
# 34         5      FA1    Bhuvneshwar Kumar         India              UPCA
# 35         5      FA1    Mustafizur Rahman    Bangladesh               NaN
# ...

# %%
 #not s in the name, top 5 result
df.loc[~(df["Player"].str.contains("s"))].head(5)
# Out:
#    Set No. Set Name           Player      Country State Association  Age  \
# 1        1        M      Trent Boult  New Zealand               NaN   32
# 3        1        M   Shikhar Dhawan        India              DDCA   36
# 7        1        M   Mohammad Shami        India               CAB   32
# 8        1        M     David Warner    Australia               NaN   35
# 9        2      BA1  Shimron Hetmyer  West Indies               NaN   25
#
#   Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 1     BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# 3    BATSMAN     LHB                     -  192.0    DCH, MI, SRH, DC
# 7     BOWLER     RHB        RIGHT ARM Fast   77.0  DCH, KKR, DD, PBKS
# 8    BATSMAN     LHB                     -  150.0             DD, SRH
# 9    BATSMAN     LHB    RIGHT ARM Leg Spin   31.0             RCB, DC
#
#   2021 Team   C/U/A Base Price Sold Price     New Franchise
# ...

# %%
# Players name starts with U in their name
df.loc[df["Player"].str.startswith("U")]
# Out:
#     Set No. Set Name       Player Country State Association  Age Specialism  \
# 38        5      FA1  Umesh Yadav   India               VCA   34     BOWLER
#
#    Batting         Bowling    IPL Previous IPLTeam(s) 2021 Team   C/U/A  \
# 38     RHB  RIGHT ARM Fast  121.0      DD, KKR,RCB,DC        DC  Capped
#
#    Base Price Sold Price          New Franchise
# 38       2 CR       2 CR  Kolkata Knight Riders

# %%
# Use of regular expression All player's name containing D in their name any where
df.loc[df["Player"].str.contains("D[a-z]*",regex=True)].head(5)
# Out:
#     Set No. Set Name            Player       Country State Association  Age  \
# 3         1        M    Shikhar Dhawan         India              DDCA   36
# 4         1        M    Faf Du Plessis  South Africa               NaN   37
# 8         1        M      David Warner     Australia               NaN   35
# 10        2      BA1      David Miller  South Africa               NaN   32
# 11        2      BA1  Devdutt Padikkal         India              KSCA   21
#
#    Specialism Batting             Bowling    IPL Previous IPLTeam(s)  \
# 3     BATSMAN     LHB                   -  192.0    DCH, MI, SRH, DC
# 4     BATSMAN     RHB  RIGHT ARM Leg Spin  100.0            RPS, CSK
# 8     BATSMAN     LHB                   -  150.0             DD, SRH
# 10    BATSMAN     LHB                   -   89.0            KXIP, RR
# 11    BATSMAN     LHB  RIGHT ARM Off Spin   29.0                 RCB
#
#    2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
# Use of regular expression All player's name containing D in their frist name and C in their Last Name or Middle Name.
df.loc[df["Player"].str.contains("D[a-z]* C[a-z]*",regex=True)]
# Out:
#      Set No. Set Name              Player      Country State Association  Age  \
# 30         5      FA1       Deepak Chahar        India               RCA   29
# 86        14      FA2  Dushmanta Chameera    Sri Lanka               NaN   30
# 111       19      BA3        Devon Conway  New Zealand               NaN   30
#
#     Specialism Batting                Bowling   IPL Previous IPLTeam(s)  \
# 30      BOWLER     RHB  RIGHT ARM Fast Medium  63.0            RPS, CSK
# 86      BOWLER     RHB         RIGHT ARM Fast   0.0                  RR
# 111    BATSMAN     LHB       RIGHT ARM Medium   NaN                 NaN
#
#     2021 Team   C/U/A Base Price Sold Price         New Franchise
# 30        CSK  Capped       2 CR      14 CR   Chennai Super Kings
# 86        NaN  Capped       50 L       2 CR  Lucknow Super Giants
# 111       NaN  Capped       1 CR       1 CR   Chennai Super Kings

# %%
# Use of regular expression All player's name containing D in their name any where with top 5 results
df.loc[df["Player"].str.contains("A[a-z]*",regex=True)].head(5)
# Out:
#     Set No. Set Name               Player Country State Association  Age  \
# 0         1        M             R Ashwin   India              TNCA   35
# 28        4      WK1        Ambati Rayudu   India               ACA   36
# 44        7     UBA1        Ashwin Hebbar   India               ACA   26
# 45        7     UBA1  Abhinav Sadarangani   India              KSCA   27
# 46        7     UBA1     Anmolpreet Singh   India               PCA   24
#
#       Specialism Batting             Bowling    IPL Previous IPLTeam(s)  \
# 0    ALL-ROUNDER     RHB  RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 28  WICKETKEEPER     RHB                   -  175.0             MI, CSK
# 44       BATSMAN     RHB    RIGHT ARM Medium    NaN                 NaN
# 45       BATSMAN     RHB  RIGHT ARM Leg Spin    NaN                 NaN
# 46       BATSMAN     RHB  RIGHT ARM Off Spin    1.0                  MI
#
#    2021 Team     C/U/A Base Price Sold Price        New Franchise
# ...

# %%
#df.loc[df["Player"].str.contains("^\A[a-z]*",regex=True)].head(5)
# Not working showing some random result

# %%
df.loc[[df['Age']>30]['Country'=='India']]
# Out:
#      Set No. Set Name               Player       Country State Association  \
# 0          1        M             R Ashwin         India              TNCA
# 1          1        M          Trent Boult   New Zealand               NaN
# 3          1        M       Shikhar Dhawan         India              DDCA
# 4          1        M       Faf Du Plessis  South Africa               NaN
# 7          1        M       Mohammad Shami         India               CAB
# 8          1        M         David Warner     Australia               NaN
# 10         2      BA1         David Miller  South Africa               NaN
# 12         2      BA1        Manish Pandey         India              KSCA
# 13         2      BA1            Jason Roy       England               NaN
# 14         2      BA1        Robin Uthappa         India               KCA
# 15         3      AL1         Dwayne Bravo   West Indies               NaN
# ...

# %%
# Use of regular expression All player's name containing P in their name any where and specialism in wicketkeeper
df.loc[(df["Player"].str.contains("P[a-z]*",regex=True))&(df["Specialism"]=="WICKETKEEPER")]
# Out:
#      Set No. Set Name             Player      Country State Association  Age  \
# 27         4      WK1    Nicholas Pooran  West Indies               NaN   26
# 61         9     UWK1  Prabhsimran Singh        India               PCA   21
# 124       21      WK2     Glenn Phillips  New Zealand               NaN   25
#
#        Specialism Batting             Bowling   IPL Previous IPLTeam(s)  \
# 27   WICKETKEEPER     LHB                   -  33.0            MI, PBKS
# 61   WICKETKEEPER     RHB                   -   5.0                PBKS
# 124  WICKETKEEPER     RHB  RIGHT ARM Off Spin   3.0                 NaN
#
#     2021 Team     C/U/A Base Price Sold Price        New Franchise
# 27       PBKS    Capped     1.5 CR   10.75 CR  Sunrisers Hyderabad
# 61       PBKS  Uncapped       20 L       60 L         Punjab Kings
# 124        RR    Capped    1.50 CR    1.50 CR  Sunrisers Hyderabad

# %%
# Players with Batting style LHB and age less then 20
df.loc[(df["Batting"]=='LHB')&(df['Age']<20)]
# Out:
#      Set No. Set Name            Player Country State Association  Age  \
# 158       33     UAL4  Aneeshwar Gautam   India              KSCA   19
#
#       Specialism Batting                 Bowling  IPL Previous IPLTeam(s)  \
# 158  ALL-ROUNDER     LHB  LEFT ARM Slow Orthodox  NaN                 NaN
#
#     2021 Team     C/U/A Base Price Sold Price                New Franchise
# 158       NaN  Uncapped       20 L       20 L  Royal Challengers Bangalore

# %%
# All Afghan Players
df.loc[df["Country"]=='Afghanistan']
# Out:
#      Set No. Set Name            Player      Country State Association  Age  \
# 69        11     USP1        Noor Ahmad  Afghanistan               NaN   17
# 128       22      FA3  Fazalhaq Farooqi  Afghanistan               NaN   21
#
#     Specialism Batting                   Bowling  IPL Previous IPLTeam(s)  \
# 69      BOWLER     RHB  LEFT ARM Slow Unorthodox  NaN                 NaN
# 128     BOWLER     RHB      LEFT ARM Fast Medium  NaN                 NaN
#
#     2021 Team     C/U/A Base Price Sold Price        New Franchise
# 69        NaN  Uncapped       30 L       30 L       Gujarat Titans
# 128       NaN    Capped       50 L       50 L  Sunrisers Hyderabad

# %%
# shorting all value with respect to Age column
df.sort_values(["Age"])
# Out:
#      Set No. Set Name                  Player       Country State Association  \
# 69        11     USP1              Noor Ahmad   Afghanistan               NaN
# 42         7     UBA1           Dewald Brevis  South Africa               NaN
# 99        17     UAL2  Rajvardhan Hangargekar         India              MACA
# 147       27     UFA3            Mayank Yadav         India              DDCA
# 180       54     UFA8            Ashok Sharma         India               RCA
# ..       ...      ...                     ...           ...               ...
# 28         4      WK1           Ambati Rayudu         India               ACA
# 14         2      BA1           Robin Uthappa         India               KCA
# 25         4      WK1          Dinesh Karthik         India              TNCA
# 4          1        M          Faf Du Plessis  South Africa               NaN
# 15         3      AL1            Dwayne Bravo   West Indies               NaN
#
# ...

# %%
 #age ascending=true and base price ascending=False
df.sort_values(["Age","Base Price"],ascending=(True,False)).head(10)
# Out:
#      Set No. Set Name                  Player       Country State Association  \
# 69        11     USP1              Noor Ahmad   Afghanistan               NaN
# 42         7     UBA1           Dewald Brevis  South Africa               NaN
# 99        17     UAL2  Rajvardhan Hangargekar         India              MACA
# 98        17     UAL2              Yash Dhull         India              DDCA
# 102       17     UAL2            Vicky Ostwal         India              MACA
# 147       27     UFA3            Mayank Yadav         India              DDCA
# 158       33     UAL4        Aneeshwar Gautam         India              KSCA
# 180       54     UFA8            Ashok Sharma         India               RCA
# 55         8     UAL1             Riyan Parag         India              ASCA
# 140       26     UWK2             Aryan Juyal         India              UPCA
#
#      Age    Specialism Batting                   Bowling   IPL  \
# ...

# %%
#by Default ascending is True
df.sort_values(["Age"],ascending=True)
# Out:
#      Set No. Set Name                  Player       Country State Association  \
# 69        11     USP1              Noor Ahmad   Afghanistan               NaN
# 42         7     UBA1           Dewald Brevis  South Africa               NaN
# 99        17     UAL2  Rajvardhan Hangargekar         India              MACA
# 147       27     UFA3            Mayank Yadav         India              DDCA
# 180       54     UFA8            Ashok Sharma         India               RCA
# ..       ...      ...                     ...           ...               ...
# 28         4      WK1           Ambati Rayudu         India               ACA
# 14         2      BA1           Robin Uthappa         India               KCA
# 25         4      WK1          Dinesh Karthik         India              TNCA
# 4          1        M          Faf Du Plessis  South Africa               NaN
# 15         3      AL1            Dwayne Bravo   West Indies               NaN
#
# ...

# %%
# Finding the Average Age of all player that are present in the DataFrame
df['Age'].mean()
# Out:
# 27.10326086956522

# %%
# Finding the Standard Deviations Age of all player that are present in the DataFrame
df["Age"].std()
# Out:
# 4.428569717841512

# %%
df["Total"]=df["Age"]+df["IPL"]

# %%
df
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
df=df.drop(columns=["New Franchise"])

# %%
df
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
newdfile=df.to_csv("new_ipl.csv")
